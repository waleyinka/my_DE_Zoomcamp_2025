  0.0|    0.5|       0.0|         0.0|     NULL|                  0.3|       19.05|           2|        1|                2.75|
# |       2| 2020-01-22 21:09:04|  2020-01-22 21:19:07|                 N|         1|          25|          97|              1|         1.59|        8.5|  0.5|    0.5|      1.96|         0.0|     NULL|                  0.3|       11.76|           1|        1|                 0.0|
# |       2| 2020-01-03 00:13:48|  2020-01-03 00:20:58|                 N|         1|          82|         129|              4|         1.79|        8.0|  0.5|    0.5|      2.32|         0.0|     NULL|                  0.3|       11.62|           1|        1|                 0.0|
# |    NULL| 2020-01-15 21:03:00|  2020-01-15 21:15:00|              NULL|      NULL|          97|          61|           NULL|        -2.11|      18.45| 2.75|    0.5|       0.0|         0.0|     NULL|                  0.3|        22.0|        NULL|     NULL|                NULL|
# |    NULL| 2020-01-05 11:00:00|  2020-01-05 11:22:00|              NULL|      NULL|         208|         160|           NULL|         10.3|      28.67| 2.75|    0.0|       0.0|        6.12|     NULL|                  0.3|       37.84|        NULL|     NULL|                NULL|
# |    NULL| 2020-01-03 10:05:00|  2020-01-03 10:19:00|              NULL|      NULL|          55|         222|           NULL|         8.52|      35.99| 2.75|    0.0|       0.0|         0.0|     NULL|                  0.3|       39.04|        NULL|     NULL|                NULL|
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+
# only showing top 20 rows

# %%
df_green.rdd.take(10)
# Out:
# [Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2020, 1, 17, 22, 1, 22), lpep_dropoff_datetime=datetime.datetime(2020, 1, 17, 22, 8, 44), store_and_fwd_flag='N', RatecodeID=1, PULocationID=97, DOLocationID=181, passenger_count=1, trip_distance=1.12, fare_amount=6.5, extra=0.5, mta_tax=0.5, tip_amount=0.0, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=7.8, payment_type=2, trip_type=1, congestion_surcharge=0.0),
#  Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2020, 1, 25, 23, 13, 37), lpep_dropoff_datetime=datetime.datetime(2020, 1, 25, 23, 21, 53), store_and_fwd_flag='N', RatecodeID=1, PULocationID=65, DOLocationID=49, passenger_count=1, trip_distance=1.5, fare_amount=7.5, extra=0.5, mta_tax=0.5, tip_amount=1.76, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=10.56, payment_type=1, trip_type=1, congestion_surcharge=0.0),
#  Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2020, 1, 12, 10, 48, 36), lpep_dropoff_datetime=datetime.datetime(2020, 1, 12, 10, 55, 50), store_and_fwd_flag='N', RatecodeID=1, PULocationID=244, DOLocationID=166, passenger_count=1, trip_distance=1.48, fare_amount=7.5, extra=0.0, mta_tax=0.5, tip_amount=1.66, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=9.96, payment_type=1, trip_type=1, congestion_surcharge=0.0),
#  Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2020, 1, 30, 17, 51, 58), lpep_dropoff_datetime=datetime.datetime(2020, 1, 30, 17, 59, 11), store_and_fwd_flag='N', RatecodeID=1, PULocationID=75, DOLocationID=262, passenger_count=1, trip_distance=0.91, fare_amount=6.5, extra=1.0, mta_tax=0.5, tip_amount=0.0, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=11.05, payment_type=2, trip_type=1, congestion_surcharge=2.75),
#  Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2020, 1, 6, 22, 53, 17), lpep_dropoff_datetime=datetime.datetime(2020, 1, 6, 23, 16, 21), store_and_fwd_flag='N', RatecodeID=5, PULocationID=260, DOLocationID=95, passenger_count=1, trip_distance=4.25, fare_amount=20.0, extra=0.0, mta_tax=0.0, tip_amount=0.0, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=20.3, payment_type=2, trip_type=2, congestion_surcharge=0.0),
#  Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2020, 1, 21, 20, 7, 36), lpep_dropoff_datetime=datetime.datetime(2020, 1, 21, 20, 30, 1), store_and_fwd_flag='N', RatecodeID=1, PULocationID=7, DOLocationID=224, passenger_count=1, trip_distance=4.96, fare_amount=19.0, extra=0.5, mta_tax=0.5, tip_amount=4.61, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=27.66, payment_type=1, trip_type=1, congestion_surcharge=2.75),
#  Row(VendorID=None, lpep_pickup_datetime=datetime.datetime(2020, 1, 1, 22, 58), lpep_dropoff_datetime=datetime.datetime(2020, 1, 1, 23, 21), store_and_fwd_flag=None, RatecodeID=None, PULocationID=41, DOLocationID=97, passenger_count=None, trip_distance=12.44, fare_amount=41.84, extra=2.75, mta_tax=0.0, tip_amount=0.0, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=44.89, payment_type=None, trip_type=None, congestion_surcharge=None),
#  Row(VendorID=1, lpep_pickup_datetime=datetime.datetime(2020, 1, 2, 8, 57, 38), lpep_dropoff_datetime=datetime.datetime(2020, 1, 2, 8, 59, 14), store_and_fwd_flag='N', RatecodeID=1, PULocationID=75, DOLocationID=75, passenger_count=1, trip_distance=0.4, fare_amount=3.5, extra=0.0, mta_tax=0.5, tip_amount=0.85, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=5.15, payment_type=1, trip_type=1, congestion_surcharge=0.0),
#  Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2020, 1, 30, 13, 42, 47), lpep_dropoff_datetime=datetime.datetime(2020, 1, 30, 13, 52, 9), store_and_fwd_flag='N', RatecodeID=1, PULocationID=41, DOLocationID=74, passenger_count=1, trip_distance=1.07, fare_amount=7.5, extra=0.0, mta_tax=0.5, tip_amount=0.0, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=8.3, payment_type=2, trip_type=1, congestion_surcharge=0.0),
#  Row(VendorID=1, lpep_pickup_datetime=datetime.datetime(2020, 1, 8, 13, 37, 31), lpep_dropoff_datetime=datetime.datetime(2020, 1, 8, 13, 42, 56), store_and_fwd_flag='N', RatecodeID=1, PULocationID=74, DOLocationID=263, passenger_count=1, trip_distance=1.6, fare_amount=6.5, extra=2.75, mta_tax=0.5, tip_amount=0.0, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=0.3, total_amount=10.05, payment_type=2, trip_type=1, congestion_surcharge=2.75)]

# %%
rdd = df_green \
    .select('lpep_pickup_datetime', 'PULocationID', 'total_amount') \
    .rdd

# %%
rdd.take(5)
# Out:
# [Row(lpep_pickup_datetime=datetime.datetime(2020, 1, 17, 22, 1, 22), PULocationID=97, total_amount=7.8),
#  Row(lpep_pickup_datetime=datetime.datetime(2020, 1, 25, 23, 13, 37), PULocationID=65, total_amount=10.56),
#  Row(lpep_pickup_datetime=datetime.datetime(2020, 1, 12, 10, 48, 36), PULocationID=244, total_amount=9.96),
#  Row(lpep_pickup_datetime=datetime.datetime(2020, 1, 30, 17, 51, 58), PULocationID=75, total_amount=11.05),
#  Row(lpep_pickup_datetime=datetime.datetime(2020, 1, 6, 22, 53, 17), PULocationID=260, total_amount=20.3)]

# %%
#to perform where/filter by datetime

from datetime import datetime

start = datetime(year=2020, month=1, day=1)

def filter_outliers(row):
    return row.lpep_pickup_datetime >= start

# %%
rows = rdd.take(10)
row = rows[0]
row
# Out:
# Row(lpep_pickup_datetime=datetime.datetime(2020, 1, 17, 22, 1, 22), PULocationID=97, total_amount=7.8)

# %%
#to perform groupby using key/value

def prepare_for_grouping(row): 
    hour = row.lpep_pickup_datetime.replace(minute=0, second=0, microsecond=0)
    zone = row.PULocationID
    key = (hour, zone)
    
    amount = row.total_amount
    count = 1
    value = (amount, count)

    return (key, value)

# %%
def calculate_revenue(left_value, right_value):
    left_amount, left_count = left_value
    right_amount, right_count = right_value
    
    output_amount = left_amount + right_amount
    output_count = left_count + right_count
    
    return (output_amount, output_count)

# %%
from collections import namedtuple

# %%
revenue_row = namedtuple('revenue_row', ['hour', 'zone', 'revenue', 'count'])

# %%
def unwrap(row):
    return revenue_row(
        hour = row[0][0], 
        zone = row[0][1], 
        revenue = row[1][0],
        count = row[1][1]
    )

# %%
from pyspark.sql import types

# %%
df_result.schema
# Out:
# StructType([StructField('hour', TimestampType(), True), StructField('zone', IntegerType(), True), StructField('revenue', DoubleType(), True), StructField('count', IntegerType(), True)])

# %%
result_schema = types.StructType([
    types.StructField('hour', types.TimestampType(), True),
    types.StructField('zone', types.IntegerType(), True),
    types.StructField('revenue', types.DoubleType(), True),
    types.StructField('count', types.IntegerType(), True)
])

# %%
df_result = rdd \
    .filter(filter_outliers) \
    .map(prepare_for_grouping) \
    .reduceByKey(calculate_revenue) \
    .map(unwrap) \
    .toDF(result_schema)

#reduceByKey takes (key, value) as input and return (key, reduced_value)

# %%
df_result.show()
# Out:
# [Stage 11:==================================================>       (7 + 1) / 8]
# +-------------------+----+------------------+-----+
# |               hour|zone|           revenue|count|
# +-------------------+----+------------------+-----+
# |2020-01-25 23:00:00|  65|            366.23|   19|
# |2020-01-03 00:00:00|  82| 335.6500000000001|   27|
# |2020-01-25 09:00:00| 259|             90.22|    2|
# |2020-01-31 14:00:00|  95|496.75000000000017|   34|
# |2020-01-06 09:00:00|  95|            590.49|   33|
# |2020-01-14 12:00:00|  97|            176.08|   12|
# |2020-01-18 21:00:00| 130|             84.16|    7|
# |2020-01-10 14:00:00| 128|              32.3|    2|
# |2020-01-04 17:00:00| 129| 524.8000000000001|   28|
# |2020-01-22 10:00:00|  33| 591.6700000000001|   27|
# |2020-01-22 10:00:00|  97|             232.4|   10|
# |2020-01-28 21:00:00|  77|            138.86|    5|
# |2020-01-28 14:00:00| 185|             43.28|    2|
# |2020-01-07 08:00:00| 145|172.01000000000002|   16|
# |2020-01-29 19:00:00|  95| 731.4199999999998|   52|
# |2020-01-02 13:00:00| 131|145.04999999999998|    4|
# |2020-01-23 16:00:00| 126|106.53999999999999|    3|
# |2020-01-08 11:00:00| 166| 427.0600000000001|   29|
# |2020-01-20 08:00:00| 260|             79.46|    7|
# |2020-01-31 07:00:00|  39|             284.0|    9|
# +-------------------+----+------------------+-----+
# only showing top 20 rows

# %%
df_result.write.parquet('tmp/green-revenue')
# Out:
# 25/09/21 15:32:36 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %%
#mapPartitions

# %%
columns = ['VendorID', 'lpep_pickup_datetime', 'PULocationID', 'DOLocationID', 'trip_distance']

duration_rdd = df_green \
    .select(columns) \
    .rdd

# %%
import pandas as pd

# %%
rows = duration_rdd.take(10)

# %%
df = pd.DataFrame(rows, columns=columns)

# %%
columns
# Out:
# ['VendorID',
#  'lpep_pickup_datetime',
#  'PULocationID',
#  'DOLocationID',
#  'trip_distance']

# %%
#model = ...

def model_predict(df):
#     y_pred = model.predict(df)
    y_pred = df.trip_distance * 5
    return y_pred

# %%
def apply_model_in_batch(rows):
    df = pd.DataFrame(rows, columns=columns)
    predictions = model_predict(df)
    df['predicted_duration'] = predictions

    for row in df.itertuples():
        yield row

# %%
df_predicts = duration_rdd \
    .mapPartitions(apply_model_in_batch)\
    .toDF() \
    .drop('Index')

# %%
df_predicts \
    .select('predicted_duration') \
    .show()
# Out:
# [Stage 17:>                                                         (0 + 1) / 1]
# +-------------------+
# | predicted_duration|
# +-------------------+
# | 5.6000000000000005|
# |                7.5|
# |                7.4|
# |               4.55|
# |              21.25|
# |               24.8|
# | 62.199999999999996|
# |                2.0|
# | 5.3500000000000005|
# |                8.0|
# | 27.450000000000003|
# | 55.199999999999996|
# |               39.5|
# | 13.600000000000001|
# | 14.450000000000001|
# |               7.95|
# |               8.95|
# |-10.549999999999999|
# |               51.5|
# | 42.599999999999994|
# +-------------------+
# only showing top 20 rows
